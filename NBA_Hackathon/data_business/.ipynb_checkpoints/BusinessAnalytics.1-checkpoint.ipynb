# %%
import pandas as pd
import statsmodels as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3>Business Analytics: We have provided a sample of 460 games (230 from the 2016-17 season and 230 from the 2017-18 season) for which your task is to predict total international viewers. To assist with your model, we have provided viewership numbers from 1,000 games by country in each of the two seasons, plus stats on team and player performance and status. Using these inputs, we would like you to predict the total number of international viewers for each of the 460 games in the test set.</h3>
#
# <em>You will be graded on Mean Absolute Percentage Error (MAPE) on Total Viewers. We selected this metric due to natural scaling in the international viewership data. Further details on each source file and on the MAPE evaluation metric are provided in the prompt PDF made available here. Please return to us a copy of testset[Team_Name].csv with the “Total Viewers” column filled in with your response variable. Please note that each question is permitted a maximum of two file attachments. Please save your answer in a .csv file and save your code, spreadsheets and all other work in a zip file.</em>
#
# <a href="https://nba.app.box.com/s/1qdbusoz1fmp1uxd4634zxxoudyv3ogc">LINK TO PROMPT .PDF</a>

# %%
# File Names
gameCSV = "game_data.csv"
playerCSV = "player_data.csv"
testCSV = "test_set.csv"
trainingCSV = "training_set.csv"

# %%
# Importing CSV Files
gameData = pd.read_csv("game_data.csv")
dfGameData = pd.DataFrame(gameData)

playerData = pd.read_csv("player_data.csv")
dfPlayerData = pd.DataFrame(playerData)

trainingSet = pd.DataFrame(pd.read_csv("training_set.csv"))

# %%
# Convert DateTime
dfGameData["Game_Date"] = pd.to_datetime(dfGameData["Game_Date"], infer_datetime_format=True)
dfPlayerData["Game_Date"] = pd.to_datetime(dfPlayerData["Game_Date"], infer_datetime_format=True)
trainingSet["Game_Date"] = pd.to_datetime(trainingSet["Game_Date"], infer_datetime_format=True)

# %%
dfGameData.isnull() == True]
# Out:
#      Season  Game_ID Game_Date Team Location  Wins_Entering_Gm  \
# 0       NaN      NaN       NaT  NaN      NaN               NaN
# 1       NaN      NaN       NaT  NaN      NaN               NaN
# 2       NaN      NaN       NaT  NaN      NaN               NaN
# 3       NaN      NaN       NaT  NaN      NaN               NaN
# 4       NaN      NaN       NaT  NaN      NaN               NaN
# 5       NaN      NaN       NaT  NaN      NaN               NaN
# 6       NaN      NaN       NaT  NaN      NaN               NaN
# 7       NaN      NaN       NaT  NaN      NaN               NaN
# 8       NaN      NaN       NaT  NaN      NaN               NaN
# 9       NaN      NaN       NaT  NaN      NaN               NaN
# 10      NaN      NaN       NaT  NaN      NaN               NaN
# 11      NaN      NaN       NaT  NaN      NaN               NaN
# 12      NaN      NaN       NaT  NaN      NaN               NaN
# 13      NaN      NaN       NaT  NaN      NaN               NaN
# 14      NaN      NaN       NaT  NaN      NaN               NaN
# 15      NaN      NaN       NaT  NaN      NaN               NaN
# 16      NaN      NaN       NaT  NaN      NaN               NaN
# 17      NaN      NaN       NaT  NaN      NaN               NaN
# 18      NaN      NaN       NaT  NaN      NaN               NaN
# 19      NaN      NaN       NaT  NaN      NaN               NaN
# 20      NaN      NaN       NaT  NaN      NaN               NaN
# 21      NaN      NaN       NaT  NaN      NaN               NaN
# 22      NaN      NaN       NaT  NaN      NaN               NaN
# 23      NaN      NaN       NaT  NaN      NaN               NaN
# 24      NaN      NaN       NaT  NaN      NaN               NaN
# 25      NaN      NaN       NaT  NaN      NaN               NaN
# 26      NaN      NaN       NaT  NaN      NaN               NaN
# 27      NaN      NaN       NaT  NaN      NaN               NaN
# 28      NaN      NaN       NaT  NaN      NaN               NaN
# 29      NaN      NaN       NaT  NaN      NaN               NaN
# ...     ...      ...       ...  ...      ...               ...
# 4890    NaN      NaN       NaT  NaN      NaN               NaN
# 4891    NaN      NaN       NaT  NaN      NaN               NaN
# 4892    NaN      NaN       NaT  NaN      NaN               NaN
# 4893    NaN      NaN       NaT  NaN      NaN               NaN
# 4894    NaN      NaN       NaT  NaN      NaN               NaN
# 4895    NaN      NaN       NaT  NaN      NaN               NaN
# 4896    NaN      NaN       NaT  NaN      NaN               NaN
# 4897    NaN      NaN       NaT  NaN      NaN               NaN
# 4898    NaN      NaN       NaT  NaN      NaN               NaN
# 4899    NaN      NaN       NaT  NaN      NaN               NaN
# 4900    NaN      NaN       NaT  NaN      NaN               NaN
# 4901    NaN      NaN       NaT  NaN      NaN               NaN
# 4902    NaN      NaN       NaT  NaN      NaN               NaN
# 4903    NaN      NaN       NaT  NaN      NaN               NaN
# 4904    NaN      NaN       NaT  NaN      NaN               NaN
# 4905    NaN      NaN       NaT  NaN      NaN               NaN
# 4906    NaN      NaN       NaT  NaN      NaN               NaN
# 4907    NaN      NaN       NaT  NaN      NaN               NaN
# 4908    NaN      NaN       NaT  NaN      NaN               NaN
# 4909    NaN      NaN       NaT  NaN      NaN               NaN
# 4910    NaN      NaN       NaT  NaN      NaN               NaN
# 4911    NaN      NaN       NaT  NaN      NaN               NaN
# 4912    NaN      NaN       NaT  NaN      NaN               NaN
# 4913    NaN      NaN       NaT  NaN      NaN               NaN
# 4914    NaN      NaN       NaT  NaN      NaN               NaN
# 4915    NaN      NaN       NaT  NaN      NaN               NaN
# 4916    NaN      NaN       NaT  NaN      NaN               NaN
# 4917    NaN      NaN       NaT  NaN      NaN               NaN
# 4918    NaN      NaN       NaT  NaN      NaN               NaN
# 4919    NaN      NaN       NaT  NaN      NaN               NaN
#
#       Losses_Entering_Gm  Team_Minutes  Final_Score  Lead_Changes  Ties  \
# 0                    NaN           NaN          NaN           NaN   NaN
# 1                    NaN           NaN          NaN           NaN   NaN
# 2                    NaN           NaN          NaN           NaN   NaN
# 3                    NaN           NaN          NaN           NaN   NaN
# 4                    NaN           NaN          NaN           NaN   NaN
# 5                    NaN           NaN          NaN           NaN   NaN
# 6                    NaN           NaN          NaN           NaN   NaN
# 7                    NaN           NaN          NaN           NaN   NaN
# 8                    NaN           NaN          NaN           NaN   NaN
# 9                    NaN           NaN          NaN           NaN   NaN
# 3              NaN            NaN             NaN          NaN        NaN
# 4              NaN            NaN             NaN          NaN        NaN
# 5              NaN            NaN             NaN          NaN        NaN
# 6              NaN            NaN             NaN          NaN        NaN
# 7              NaN            NaN             NaN          NaN        NaN
# 8              NaN            NaN             NaN          NaN        NaN
# 9              NaN            NaN             NaN          NaN        NaN
# 10             NaN            NaN             NaN          NaN        NaN
# 11             NaN            NaN             NaN          NaN        NaN
# 12             NaN            NaN             NaN          NaN        NaN
# 13             NaN            NaN             NaN          NaN        NaN
# 14             NaN            NaN             NaN          NaN        NaN
# 15             NaN            NaN             NaN          NaN        NaN
# 16             NaN            NaN             NaN          NaN        NaN
# 17             NaN            NaN             NaN          NaN        NaN
# 18             NaN            NaN             NaN          NaN        NaN
# 19             NaN            NaN             NaN          NaN        NaN
# 20             NaN            NaN             NaN          NaN        NaN
# 21             NaN            NaN             NaN          NaN        NaN
# 22             NaN            NaN             NaN          NaN        NaN
# 23             NaN            NaN             NaN          NaN        NaN
# 24             NaN            NaN             NaN          NaN        NaN
# 25             NaN            NaN             NaN          NaN        NaN
# 26             NaN            NaN             NaN          NaN        NaN
# 27             NaN            NaN             NaN          NaN        NaN
# 28             NaN            NaN             NaN          NaN        NaN
# 29             NaN            NaN             NaN          NaN        NaN
# ...            ...            ...             ...          ...        ...
# 4890           NaN            NaN             NaN          NaN        NaN
# 4891           NaN            NaN             NaN          NaN        NaN
# 4892           NaN            NaN             NaN          NaN        NaN
# 4893           NaN            NaN             NaN          NaN        NaN
# 4894           NaN            NaN             NaN          NaN        NaN
# 4895           NaN            NaN             NaN          NaN        NaN
# 4896           NaN            NaN             NaN          NaN        NaN
# 4897           NaN            NaN             NaN          NaN        NaN
# 4898           NaN            NaN             NaN          NaN        NaN
# 4899           NaN            NaN             NaN          NaN        NaN
# 4900           NaN            NaN             NaN          NaN        NaN
# 4901           NaN            NaN             NaN          NaN        NaN
# 4902           NaN            NaN             NaN          NaN        NaN
# 4903           NaN            NaN             NaN          NaN        NaN
# 4904           NaN            NaN             NaN          NaN        NaN
# 4905           NaN            NaN             NaN          NaN        NaN
# 4906           NaN            NaN             NaN          NaN        NaN
# 4907           NaN            NaN             NaN          NaN        NaN
# 4908           NaN            NaN             NaN          NaN        NaN
# 4909           NaN            NaN             NaN          NaN        NaN
# 4910           NaN            NaN             NaN          NaN        NaN
# 4911           NaN            NaN             NaN          NaN        NaN
# 4912           NaN            NaN             NaN          NaN        NaN
# 4913           NaN            NaN             NaN          NaN        NaN
# 4914           NaN            NaN             NaN          NaN        NaN
# 4915           NaN            NaN             NaN          NaN        NaN
# 4916           NaN            NaN             NaN          NaN        NaN
# 4917           NaN            NaN             NaN          NaN        NaN
# 4918           NaN            NaN             NaN          NaN        NaN
# 4919           NaN            NaN             NaN          NaN        NaN
#
# [4920 rows x 16 columns]
